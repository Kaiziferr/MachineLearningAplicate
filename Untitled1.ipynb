# %%
import pandas as pd

# %%
movies = pd.read_csv('./peliculasDataMala.csv',encoding='utf-8')
movies
# Out:
#                                             movie_title  title_year  \
# 0                                               Avatar       2009.0
# 1             Pirates of the Caribbean: At World's End       2007.0
# 2                                              Spectre       2015.0
# 3                                The Dark Knight Rises       2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...         NaN
# 5                                          John Carter       2012.0
# 6                                         Spider-Man 3       2007.0
# 7                                              Tangled       2010.0
# 8                              Avengers: Age of Ultron       2015.0
# 9               Harry Potter and the Half-Blood Prince       2009.0
# 10                  Batman v Superman: Dawn of Justice       2016.0
# 11                                    Superman Returns       2006.0
# 12                                   Quantum of Solace       2008.0
# ...

# %%
pd.options.display.max_rows = 5043

# %%
movies['cast_total_facebook_likes']
# Out:
# 0         4834
# 1        48350
# 2        11700
# 3       106759
# 4          143
# 5         1873
# 6        46055
# 7         2036
# 8        92000
# 9        58753
# 10       24450
# 11       29991
# 12        2023
# 13       48486
# 14       45757
# 15       20495
# 16       22697
# 17       87697
# 18       54083
# 19       12572
# 20        9152
# 21       28489
# 22        3244
# 23        9152
# 24       24106
# 25        7123
# 26       45223
# 27       64798
# 28       26679
# 29        8458
# 30        2039
# 31       43388
# 32       30426
# 33       79957
# 34       21714
# 35       14863
# 36        3218
# 37        3988
# 38       73441
# 39       28631
# 40       25550
# 41        4482
# 42       17657
# 43       19085
# 44       27468
# 45       79150
# 46       32392
# 47       91434
# 48       21411
# 49        1766
# 50       29770
# 51       16149
# 52       19166
# 53        2593
# 54       14959
# 55         696
# 56        5005
# 57        1327
# ...

# %%
movies['cast_total_facebook_likes'].dtypes == 'int64'
# Out:
# True
